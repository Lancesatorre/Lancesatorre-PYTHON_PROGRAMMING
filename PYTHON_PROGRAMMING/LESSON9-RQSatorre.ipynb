# %% [markdown]
# ### Lance Timothy B. Satorre
# # LESSON 9

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats

# %%
X, y = make_blobs(n_samples=300, centers=3, cluster_std=1.0, random_state=1500)
data = pd.DataFrame(X, columns=['Feature1', 'Feature2'])
data['TrueLabel'] = y
data.head()
# Out:
#    Feature1  Feature2  TrueLabel
# 0  5.718289 -7.346090          1
# 1  4.513303 -5.571346          1
# 2  2.719567  7.194522          2
# 3  4.200706 -7.978844          1
# 4  2.515505  7.201867          2

# %%
import os
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
os.environ['OMP_NUM_THREADS'] = '2'
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=2, random_state=100)
kmeans.fit(X)
data['KMeansLabel'] = kmeans.predict(X)

# %%
plt.figure(figsize=(15,6))
plt.scatter(data['Feature1'], data['Feature2'], c=data['KMeansLabel'], cmap='viridis', s=100)
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], c='red', marker='+', s=50, label='Centroids')
plt.title("KMeans Clustering")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.show()
